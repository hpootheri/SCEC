# %% [raw]
# Pull Napa, Ridgecrest, and Current (post-Ridgecrest) schema and observations from ScienceBase.
# Current schema is in a csv file (no observations).

# %%
# reset all variables
# %reset -f

# %%
import requests
import zipfile
import io
import pandas as pd
import xml.etree.ElementTree as ET
import os

# %%
# post_ridgecrest_schema_local_filename = r'C:\Users\lblair\Documents\Data\SCEC\post_ridgecrest_schema.csv'
post_ridgecrest_schema_local_filename = 'post_ridgecrest_schema.csv'

# %% [markdown]
# ### Napa observation table

# %% [raw]
# Napa observation database on USGS ScienceBase
# https://www.sciencebase.gov/catalog/item/5c1a392de4b0708288c2e9a5

# %%
# --- fetch Napa XML metadata from ScienceBase ---
item_id = '5c1a392de4b0708288c2e9a5'
sb_json_url = f'https://www.sciencebase.gov/catalog/item/{item_id}?format=json'
# sb_json_url = f'https://www.sciencebase.gov/catalog/item/5c1a392de4b0708288c2e9a5?format=json'
response = requests.get(sb_json_url)
data = response.json()

# Find the XML URL
xml_url = None
for file in data.get("files", []):
    if file["name"] == "Observations.xml":
        xml_url = file["url"]
        break

# Load and parse XML
if xml_url:
    xml_response = requests.get(xml_url)
    napa_xml_root = ET.fromstring(xml_response.content)

    # Extract schema definitions from XML
    def extract_schema_from_xml(root):
        records = []
        for attr in root.iter():
            if attr.tag.endswith('attr'):
                name = attr.findtext('.//attrlabl')
                definition = attr.findtext('.//attrdef')
                if name:
                    records.append({
                        'Field': name.strip(),
                        'Definition': definition.strip() if definition else ''
                    })
        return pd.DataFrame(records)

    napa_schema_df = extract_schema_from_xml(napa_xml_root)

    # Load Observations.txt into DataFrame
    txt_url = next((f["url"] for f in data.get("files", []) if f["name"] == "Observations.txt"), None)
    if txt_url:
        napa_df = pd.read_csv(txt_url, sep='\t')

        # Merge schema with actual columns
        napa_merged_schema = pd.DataFrame({'Field': napa_df.columns})
        napa_merged_schema = pd.merge(napa_merged_schema, napa_schema_df, on='Field', how='left')
        napa_merged_schema.head(25)
    else:
        print("Observations.txt not found.")
else:
    print("Observations.xml not found.")

# %%
napa_df.head(5)
# Out:
#    stnid  intid citation    obs_date   latitude   longitude   orig_lat  \
# 0    1.0    161      NaN  2014:09:11  38.205764 -122.309377  38.205902
# 1    2.0    790      NaN  2014:08:26  38.206033 -122.299086  38.206028
# 2    3.0    791      NaN  2014:08:26  38.206754 -122.300993  38.206795
# 3    4.0    792      NaN  2014:08:26  38.207986 -122.305738  38.208069
# 4    5.0    163      NaN  2014:09:11  38.208184 -122.309187  38.208134
#
#      orig_lon photo   observer  ...  \
# 0 -122.309395     Y     DeLong  ...
# 1 -122.299070     Y  Lancaster  ...
# 2 -122.300972     Y  Lancaster  ...
# 3 -122.305672     Y  Lancaster  ...
# 4 -122.309158     Y     DeLong  ...
#
#                                          description fault_azimuth  \
# 0  Minor cracking; no obvious offset; possibly ol...           NaN
# 1  Mole tracks along levee. Trend 320 azimuth. Ab...           320
# 2  Northeast trending fractures through levee. 2-...            10
# 3  Faint mole track in levee. Roughly 4 in wide w...           310
# 4  Cracking. Compiler note: On UAVSAR lineament t...           NaN
#
#   ss_displacement ss_sense ext_offset comp_offset vert_offset upthrown_side  \
# 0             NaN      NaN        NaN         NaN         NaN           NaN
# 1             NaN      NaN        NaN         NaN         NaN           NaN
# 2             NaN      NaN        NaN         NaN         NaN           NaN
# 3             NaN      NaN        NaN         NaN         NaN           NaN
# 4             NaN      NaN        NaN         NaN         NaN           NaN
#
#   trace     origin
# 0     A  Uncertain
# 1     A  Uncertain
# 2     A  Uncertain
# 3     A  Uncertain
# 4     A   Tectonic
#
# [5 rows x 21 columns]

# %%
# Print the schema
napa_df.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1222 entries, 0 to 1221
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   stnid             1221 non-null   float64
#  1   intid             1222 non-null   int64
#  2   citation          84 non-null     object
#  3   obs_date          1222 non-null   object
#  4   latitude          1222 non-null   float64
#  5   longitude         1222 non-null   float64
#  6   orig_lat          1220 non-null   float64
#  7   orig_lon          1220 non-null   float64
#  8   photo             1222 non-null   object
#  9   observer          1222 non-null   object
#  10  observed_feature  1222 non-null   object
#  11  description       811 non-null    object
#  12  fault_azimuth     177 non-null    object
#  13  ss_displacement   166 non-null    object
#  14  ss_sense          243 non-null    object
#  15  ext_offset        131 non-null    object
#  16  comp_offset       12 non-null     object
#  17  vert_offset       46 non-null     object
#  18  upthrown_side     54 non-null     object
#  19  trace             1221 non-null   object
#  20  origin            1221 non-null   object
# dtypes: float64(5), int64(1), object(15)
# memory usage: 200.6+ KB

# %%
# column definitions
with pd.option_context('display.max_colwidth', None):
    display(napa_merged_schema)
# Out:
#                Field  \
# 0              stnid
# 1              intid
# 2           citation
# 3           obs_date
# 4           latitude
# 5          longitude
# 6           orig_lat
# 7           orig_lon
# 8              photo
# 9           observer
# 10  observed_feature
# 11       description
# 12     fault_azimuth
# 13   ss_displacement
# 14          ss_sense
# 15        ext_offset
# 16       comp_offset
# 17       vert_offset
# 18     upthrown_side
# 19             trace
# 20            origin
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           Definition
# 0                                                                                                                                     Identifier for the observation station. A station is assigned where descriptions, displacement measurements and (or) photographs have been obtained at a site at a given date and time by an observer or group of observers working together. Repeat observations at different times by the same observer or group of observers are assigned different stnids.
# 1                                                                                                                                                                                                                                                                                                                                                                                                 Internal identifier. Used to link an observation record to associated records in the Photos table.
# 2                                                                                                                                                                                                                                                                                                                                                                                  If the data or photographs from this observation are published elsewhere, the original publication is cited here.
# 3                                                                                                                                                                                                                                                                                                                                                                                                                                Date of the observation as year, numerical month, and day of month.
# 4                  Latitude coordinate of the station in decimal degrees, WGS84 datum. These values are derived either from the coordinate provided directly by the observer, or are digitized during compilation using airborne imagery and ground photographs to more accurately locate the station on the feature of interest. Observations of fault features were typically relocated to coincide with mapped fault locations as derived from high-resolution imagery, lidar data or InSAR data.
# 5                 Longitude coordinate of the station in decimal degrees, WGS84 datum. These values are derived either from the coordinate provided directly by the observer, or are digitized during compilation using airborne imagery and ground photographs to more accurately locate the station on the feature of interest. Observations of fault features were typically relocated to coincide with mapped fault locations as derived from high-resolution imagery, lidar data or InSAR data.
# 6                                                                                                                                                                                                                                                                                                                                                                                                                        Original latitude reported by the observer in decimal degrees, WGS84 datum.
# 7                                                                                                                                                                                                                                                                                                                                                                                                                       Original longitude reported by the observer in decimal degrees, WGS84 datum.
# 8                                                                                                                                                                                                                                                                                                                                                                                                                                          Indicates if photographs are associated with this station
# 9                                                                                                                                                                                                         Last name of the observer or observers who provided the information/photographs. Full names and affiliations are listed in the data set credit of this metadata record. A single name may be listed where observations may have been collected by a group of individuals working together.
# 10                                                                                                                                                                                                                                                                                                                                                                                         The type of feature where fault offset is observed or the type of materials that are offset or disturbed.
# 11                                                                                                                                                                                                                                      Notes and descriptive information provided by the observer, if applicable. Descriptions are edited to correct typographical and grammatical errors, and to remove irrelevant or personal information, such as property owner names and addresses, and so on.
# 12                                                                                                                                                                                                                                                                                         Strike of the fault zone in degrees from true north (0–360). If qualified by a double asterisk (**), the fault azimuth is estimated by the compilers from the rupture map and used for slip calculations.
# 13  Strike-slip displacement, the length of the horizontal component of total slip on the fault plane, in centimeters. If qualified by an asterisk (*) the value is reported as an approximation or represents some undocumented component of horizontal fault movement, such as separation normal to a faulted feature or piercing point separation. If qualified by a double asterisk (**), strike-slip component is computed by the compilers using a fault azimuth value estimated from the map.
# 14                                                                                                                                                                                                                                                                                                                                                                                    Sense of strike-slip displacement, either reported or computed from slip vector information and fault azimuth.
# 15                                                                                                                                                                                                        The amount of horizontal opening (extension) measured normal to the fault plane, in centimeters. If qualified by an asterisk (*), value is an estimate. If qualified by a double asterisk (**), extension is computed by the compilers using a fault azimuth value estimated from the map.
# 16                                                                                                                                                                                                                                                                                                                                 The amount of horizontal shortening (compression) measured normal to the fault plane, in centimeters. If qualified by an asterisk (*), value is an approximation.
# 17                                                                                                                                                                                                                                                                                                                                                                      The vertical component of dip-slip displacement, in centimeters. If qualified by an asterisk (*), value is an approximation.
# 18                                                                                                                                                                                                                                                                                                                                                                                   If a vertical component of fault displacement is reported, this is the cardinal direction of the upthrown side.
# 19                                                                                                                                                                                                                                                                                                                                                                                                                Identifies the fault trace (A-G) or region (H-U) where the observation is located.
# 20                                                                                                                                                                                                                                                                             Interpreted cause of the ground deformation observed at the station, either inferred directly from the observation or from context based on fracture orientation, displacement sense, setting or nearby observations.

# %%
print(f'number of Napa observations: {len(napa_df)}')
# Out:
# number of Napa observations: 1222

# %% [markdown]
# ### Ridgecrest Observation Table

# %% [raw]
# Ridgecrest USGS ScienceBase data
# https://www.sciencebase.gov/catalog/item/5f021cec82ce0afb24469b04

# %%
# Step 1: ScienceBase item ID and JSON metadata URL
item_id = '5ef18f7f82ced62aaae19257'
sb_json_url = f'https://www.sciencebase.gov/catalog/item/{item_id}?format=json'

# Step 2: Get metadata from ScienceBase
response = requests.get(sb_json_url)
data = response.json()

# Step 3: Find the ZIP file and XML metadata file URLs
zip_url = None
xml_url = None
for file in data.get('files', []):
    if file['name'] == 'CSV_File_Ridgecrest_Observations_Slip_Prov_Rel_1.zip':
        zip_url = file['url']
    elif file['name'] == 'Ridgecrest_Observations_Slip_Prov_Rel_1.xml':
        xml_url = file['url']

# Step 4: Download and extract the CSV file
if zip_url and xml_url:
    zip_response = requests.get(zip_url)
    with zipfile.ZipFile(io.BytesIO(zip_response.content)) as z:
        csv_name = next(
            name for name in z.namelist()
            if name.endswith('.csv') and not name.startswith('__MACOSX')
        )
        with z.open(csv_name) as csvfile:
            df_ridgecrest = pd.read_csv(csvfile)

    # Step 5: Download and parse the XML file
    xml_response = requests.get(xml_url)
    ridgecrest_xml_root = ET.fromstring(xml_response.content)

    # Step 6: Extract schema from XML
    def extract_schema_from_xml(root):
        records = []
        for attr in root.iter():
            if attr.tag.endswith('attr'):
                name = attr.findtext('.//attrlabl')
                definition = attr.findtext('.//attrdef')
                if name:
                    records.append({
                        'Field': name.strip(),
                        'Definition': definition.strip() if definition else ''
                    })
        return pd.DataFrame(records)

    ridgecrest_schema_df = extract_schema_from_xml(ridgecrest_xml_root)

    # Step 7: Merge schema with DataFrame columns
    merged_ridgecrest_schema = pd.DataFrame({'Field': df_ridgecrest.columns})
    merged_ridgecrest_schema = pd.merge(merged_ridgecrest_schema, ridgecrest_schema_df, on='Field', how='left')

    pd.set_option('display.max_colwidth', None)
    merged_ridgecrest_schema.head(25)
else:
    print("ZIP or XML file not found.")

# %%
df_ridgecrest.head(5)
# Out:
#    intid       origid    observer obs_affiliation    team_id  \
# 0     19           19  G. Funning             UCR  '07/04-2'
# 1     22  Red Point 3   C. Madugo            PG&E  '07/05-5'
# 2  28826            1   I. Pierce             UNR  '07/05-4'
# 3  28827            2   I. Pierce             UNR  '07/05-4'
# 4  28829            4   I. Pierce             UNR  '07/05-4'
#
#                                                             team obs_position  \
# 0                                                 G. Funning/UCR      At Site
# 1  C. Hitchcock/InfraTerra\nO. Kozaci/InfraTerra\nC. Madugo/PG&E      At Site
# 2                  B. Brooks/USGS\nR. Koehler/UNR\nI. Pierce/UNR      At Site
# 3                  B. Brooks/USGS\nR. Koehler/UNR\nI. Pierce/UNR      At Site
# 4                  B. Brooks/USGS\nR. Koehler/UNR\nI. Pierce/UNR      At Site
#
#                  obs_date    origin source  ... vert_slip_type heave_type  \
# 0  2019-07-04T19:37:17-07  Tectonic    6.4  ...            NaN        NaN
# 1  2019-07-05T00:00:00-07  Tectonic    6.4  ...            NaN        NaN
# 2  2019-07-05T07:38:29-07  Tectonic    6.4  ...            NaN  Extension
# 3  2019-07-05T07:41:44-07  Tectonic    6.4  ...            NaN  Extension
# 4  2019-07-05T09:00:32-07  Tectonic    6.4  ...     Separation  Extension
#
#    heave_min  heave_pref  heave_max   latitude   longitude   orig_lat  \
# 0        NaN         NaN        NaN  35.644039 -117.536706  35.644039
# 1        NaN         NaN        NaN  35.623983 -117.567485  35.623983
# 2        NaN        60.0        NaN  35.639533 -117.540619  35.639533
# 3        NaN        30.0        NaN  35.639899 -117.539949  35.639899
# 4        NaN         NaN        1.0  35.637147 -117.544223  35.637147
#
#      orig_lon                                    note
# 0 -117.536706  Measurement estimated from photograph.
# 1 -117.567485           Observation time not reported
# 2 -117.540619                                     NaN
# 3 -117.539949                                     NaN
# 4 -117.544223                                     NaN
#
# [5 rows x 63 columns]

# %%
# Print the schema
df_ridgecrest.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130 entries, 0 to 1129
# Data columns (total 63 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   intid                   1130 non-null   int64
#  1   origid                  1088 non-null   object
#  2   observer                1130 non-null   object
#  3   obs_affiliation         1130 non-null   object
#  4   team_id                 1130 non-null   object
#  5   team                    1129 non-null   object
#  6   obs_position            1130 non-null   object
#  7   obs_date                1130 non-null   object
#  8   origin                  1130 non-null   object
#  9   source                  1129 non-null   object
#  10  citation                1 non-null      object
#  11  description             1067 non-null   object
#  12  fault_az_min            86 non-null     float64
#  13  fault_az_pref           724 non-null    float64
#  14  fault_az_max            90 non-null     float64
#  15  fault_dip_min           1 non-null      float64
#  16  fault_dip_pref          18 non-null     float64
#  17  fault_dip_max           1 non-null      float64
#  18  local_frac_az_min       16 non-null     float64
#  19  local_frac_az_pref      113 non-null    float64
#  20  local_frac_az_max       18 non-null     float64
#  21  rup_width_min           41 non-null     float64
#  22  rupture_width_pref      331 non-null    float64
#  23  rup_width_max           70 non-null     float64
#  24  fault_expression        484 non-null    object
#  25  scarp_facing_direction  447 non-null    object
#  26  striations_observed     274 non-null    object
#  27  gouge_observed          271 non-null    object
#  28  sense                   1064 non-null   object
#  29  observed_feature        649 non-null    object
#  30  feature_type            554 non-null    object
#  31  vector_length_min       22 non-null     float64
#  32  vector_length_pref      84 non-null     float64
#  33  vector_length_max       23 non-null     float64
#  34  vect_plunge_min         4 non-null      float64
#  35  vect_plunge_pref        28 non-null     float64
#  36  vect_plunge_max         4 non-null      float64
#  37  vect_az_min             11 non-null     float64
#  38  vect_az_pref            111 non-null    float64
#  39  vect_az_max             12 non-null     float64
#  40  aperture_min            9 non-null      float64
#  41  aperture_pref           127 non-null    float64
#  42  aperture_max            10 non-null     float64
#  43  horiz_offset_min        464 non-null    float64
#  44  horiz_offset_pref       608 non-null    float64
#  45  horiz_offset_max        530 non-null    float64
#  46  horiz_slip_type         472 non-null    object
#  47  horiz_az_min            39 non-null     float64
#  48  horiz_az_pref           198 non-null    float64
#  49  horiz_az_max            40 non-null     float64
#  50  vert_offset_min         301 non-null    float64
#  51  vert_offset_pref        437 non-null    float64
#  52  vert_offset_max         359 non-null    float64
#  53  vert_slip_type          582 non-null    object
#  54  heave_type              85 non-null     object
#  55  heave_min               27 non-null     float64
#  56  heave_pref              68 non-null     float64
#  57  heave_max               36 non-null     float64
#  58  latitude                1130 non-null   float64
#  59  longitude               1130 non-null   float64
#  60  orig_lat                1130 non-null   float64
#  61  orig_lon                1130 non-null   float64
#  62  note                    268 non-null    object
# dtypes: float64(40), int64(1), object(22)
# memory usage: 556.3+ KB

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None, 'display.max_colwidth', None):
    display(ridgecrest_schema_df)
# Out:
#                      Field  \
# 0                    intid
# 1                   origid
# 2                 observer
# 3          obs_affiliation
# 4                  team_id
# 5                     team
# 6             obs_position
# 7                 obs_date
# 8                   origin
# 9                   source
# 10                citation
# 11             description
# 12            fault_az_min
# 13           fault_az_pref
# 14            fault_az_max
# 15           fault_dip_min
# 16          fault_dip_pref
# 17           fault_dip_max
# 18       local_frac_az_min
# 19      local_frac_az_pref
# 20       local_frac_az_max
# 21           rup_width_min
# 22      rupture_width_pref
# 23           rup_width_max
# 24        fault_expression
# 25  scarp_facing_direction
# 26     striations_observed
# 27          gouge_observed
# 28                   sense
# 29        observed_feature
# 30            feature_type
# 31       vector_length_min
# 32      vector_length_pref
# 33       vector_length_max
# 34         vect_plunge_min
# 35        vect_plunge_pref
# 36         vect_plunge_max
# 37             vect_az_min
# 38            vect_az_pref
# 39             vect_az_max
# 40            aperture_min
# 41           aperture_pref
# 42            aperture_max
# 43        horiz_offset_min
# 44       horiz_offset_pref
# 45        horiz_offset_max
# 46         horiz_slip_type
# 47            horiz_az_min
# 48           horiz_az_pref
# 49            horiz_az_max
# 50         vert_offset_min
# 51        vert_offset_pref
# 52         vert_offset_max
# 53          vert_slip_type
# 54              heave_type
# 55               heave_min
# 56              heave_pref
# 57               heave_max
# 58                latitude
# 59               longitude
# 60                orig_lat
# 61                orig_lon
# 62                    note
#
#                                                                                                                                                                                                                                                                                                                                                                                                                                                          Definition
# 0                                                                                                                                                                                                                                                                                                                                                                                                                    Observation identifier assigned at compilation
# 1                                                                                                                                                                                                                                                                                                                                                                                             Original name or ID of observation station as defined by the observer
# 2                                                                                                                                                                                                                                                                                                                                                                                                                 The principal team member making the observation.
# 3                                                                                                                                                                                                                                                                                                                                                                                                The agency or organization affiliated with the principal observer.
# 4                                                                                                                                                                                                                                                                                                                                                                                                                                             Field team identifier
# 5                                                                                                                                                                                                                                                                                                                                                                                                                                                      Team members
# 6                                                                                                                                                                                                                                                                                                                                                                                                  The location of the observer relative to the actual deformation.
# 7   The date and time that the observation was made. A textual description of the date\nas numeric values of the year, month, day separated by dashes. Time of observation is\npresented after the letter "T" with hours, minutes, seconds each separated by a colon and\nfollowed by a time zone offset. For example, 2019-07-05T17:44:55-07 represents July 5,\n2019, at 5:44 PM and 55 seconds, with a time zone offset of -7 hours before Greenwich Mean\nTime.
# 8                                                                                                                                                                                                                                                                                   An enumerated value describing the inferred origin of the observed feature, based\non ground observations and other factors such as rupture continuity and surface\nexpression.
# 9                                                                                                                                                                                                                                                                                                                                                 The earthquake presumed to have produced the observed deformation (M6.4 - July 4),\n(M7.1 - July 5), or Uncertain
# 10                                                                                                                                                                                                                                                                                                                                                                            The citation to a published source if the observation's data is published\nelsewhere.
# 11                                                                                                                                                                                                                                                                                                                                                                                                      Description at the site, including any observer notes, etc.
# 12                                                                                                                                                                                                                                                                                                                                                                                                     Minimum value for fault strike or azimuth in degrees of arc.
# 13                                                                                                                                                     Preferred value for the strike of the fault, expressed as an azimuth in bearing\nform (0-360 degrees arc, 0 degrees = true north, right-hand rule relative to fault dip\ndirection if known). Bearing should be taken over a relatively long baseline - 10s of\nmeters if possible - centered over the site.
# 14                                                                                                                                                                                                                                                                                                                                                                                                     Maximum value for fault strike or azimuth in degrees of arc.
# 15                                                                                                                                                                                                                                                                                                                                                                                                                Estimate of the minimum fault dip in degrees arc.
# 16                                                                                                                                                                                                                                                                                                                                                        Preferred value for dip of the fault as observed, in degrees arc (0-90 degrees, 0\ndegrees = horizontal).
# 17                                                                                                                                                                                                                                                                                                                                                                                                                Estimate of the maximum fault dip in degrees arc.
# 18                                                                                                                                                                                                                                                                                                                                                                        Estimate of the minimum value of the local fracture azimuth measurement, in degrees\narc.
# 19                                                                                                                                                                                                          Preferred value for the strike of the local fracture where a measurement is taken;\nvalues that differ from the overall strike of the fault typically occur where fault is\nexpressed as en echelon fractures; in degrees arc (0 degrees = true north).
# 20                                                                                                                                                                                                                                                                                                                                                                        Estimate of the maximum value of the local fracture azimuth measurement, in degrees\narc.
# 21                                                                                                                                                                                                                                                                                                                                                                                                              Estimate of the minimum value of the rupture width.
# 22                                                                                                                                                                                                                                                                                                                                                            Preferred value for the width of the rupture zone in meters, measured normal to\nstrike of the fault.
# 23                                                                                                                                                                                                                                                                                                                                                                                                   Estimate of the maximum value of the rupture width, in meters.
# 24                                                                                                                                                                                                                                                                                                                                                                                           A term describing the principal morphology of deformation at the site.
# 25                                                                                                                                                                                                                                                                                                                                        Cardinal direction that the fault scarp faces (eg. the down-dropped side). Allowed\nvalues are: North, East, South, West.
# 26                                                                                                                                                                                                                                                                                                                                                                                               Yes or No if fault plane is exposed and striations are observable.
# 27                                                                                                                                                                                                                                                                                                                                                                                                     Yes or No if fault plane is exposed and gouge is observable.
# 28                                                                                                                                                                                                                                                                                                                                                                                                                             Dominant sense of slip on the fault.
# 29                                                                                                                                                                                                                                                                                                                                        The faulted or deformed feature that is being observed or measured (eg. soil,\nchannel margin, pavement, road edge, etc).
# 30                                                                                                                                                                                                                                                                                                                                                                                                                                   Offset feature classification.
# 31                                                                                                                                                                                                                                                                                                                                                                                                                      Estimate of the minimum slip vector length.
# 32                                                                                                                                                                                                                                                                                                                              Preferred value for the length of the slip vector, in cm. This is the total slip on\nthe fault plane that connects piercing points.
# 33                                                                                                                                                                                                                                                                                                                                                                                                                  Estimated maximum value for slip vector length.
# 34                                                                                                                                                                                                                                                                                                                                                                                                            Estimate of the minimum vector plunge in degrees arc.
# 35                                                                                                                                                                                                                                                                                                                                                     Preferred value for the plunge of the slip vector, in degrees arc (0 - 90 degrees;\n0 degrees = horizontal).
# 36                                                                                                                                                                                                                                                                                                                                                                                                            Estimate of the maximum vector plunge in degrees arc.
# 37                                                                                                                                                                                                                                                                                                                                                                                                                      Minimum slip vector azimuth, in degrees arc
# 38                                                                                                                                                                                                                                                                                                                                               Preferred value for the slip vector azimuth (0-360 degrees in the down-plunge\ndirection; 0 degrees = true north).
# 39                                                                                                                                                                                                                                                                                                                                                                                                                                     Maximum slip vector azimuth.
# 40                                                                                                                                                                                                                                                                                                                                                                                                         Estimate of the minimum value of the aperture in meters.
# 41                                                                                                                                                                                                                                                                                                                                                                     The length, in meters, measured normal to the fault across which the measurement\nwas taken.
# 42                                                                                                                                                                                                                                                                                                                                                                                                Estimate of the maximum measurement aperture distance, in meters.
# 43                                                                                                                                                                                                                                                                                                                                                                                                  Estimate of the minimum horizontal offset or separation, in cm.
# 44                                                                                                                                                                                                                                                                     The preferred amount of horizontal offset or separation, in centimeters. This is\nthe horizontal component of the slip vector or the horizontal separation of any displaced\noffset feature.
# 45                                                                                                                                                                                                                                                                                                                                                                           Estimate of the maximum value of the horizontal offset or separation, in\ncentimeters.
# 46                                                                                                                                                                                                                                                                                                                                                                                                                                Horizontal offset classification.
# 47                                                                                                                                                                                                                                                                                                                                                                                        Estimate of the minimum value of the azimuth measurement, in degrees arc.
# 48                                                                                                                                                                                                                                                                                                       Preferred value of the azimuth of the horizontal offset component, or lateral\nseparation of feature, as a bearing - in down plunge or down dip direction.
# 49                                                                                                                                                                                                                                                                                                                                                                                        Estimate of the maximum value of the azimuth measurement, in degrees arc.
# 50                                                                                                                                                                                                                                                                                                                                                                                                     Estimate of the minimum value of the vertical offset, in cm.
# 51                                                                                                                                                                                                                                                           The preferred value for the amount of vertical displacement of the fault piercing\npoint, in centimeters, or the measured value of the vertical separation of the land\nsurface (vertical separation).
# 52                                                                                                                                                                                                                                                                                                                                                                                                     Estimate of the maximum value of the vertical offset, in cm.
# 53                                                                                                                                                                                                                                                                                                                                                                                                                                 Classification of vertical slip.
# 54                                                                                                                                                                                                                                                                                                                                                                                                                            Type of offset normal to fault plane.
# 55                                                                                                                                                                                                                                                                                                                                                                   Estimate of the minimum value of the extensional or compressional component across\nthe fault.
# 56                                                                                                                                                                                                                                                                                                                                                         Preferred value for the component of slip normal to the fault that represents\nextension or compression.
# 57                                                                                                                                                                                                                                                                                                                                                                   Estimate of the maximum value of the extensional or compressional component across\nthe fault.
# 58                                                                                                                                                                                                                                                                                                                                                                                                                                                Updated latitude.
# 59                                                                                                                                                                                                                                                                                                                                                                                                                                               Updated longitude.
# 60                                                                                                                                                                                                                                                                                                                                                                                                                                 Latitude as originally reported.
# 61                                                                                                                                                                                                                                                                                                                                                                                                                                Longitude as originally reported.
# 62                                                                                                                                                                                                                                                                                                                                                                                                                                                  Compiler notes.

# %%
print(f'number of Ridgecrest observations: {len(df_ridgecrest)}')
# Out:
# number of Ridgecrest observations: 1130

# %% [markdown]
# ### Post-Ridgecrest Schema

# %%
# Read CSV into DataFrame
df_current_schema = pd.read_csv(post_ridgecrest_schema_local_filename)
df_current_schema
# Out:
#     Unnamed: 0                     Field Name                 Field Type  \
# 0            0                       OBJECTID           esriFieldTypeOID
# 1            1                     Station_ID        esriFieldTypeString
# 2            2                 Feature_Origin        esriFieldTypeString
# 3            3                          Notes        esriFieldTypeString
# 4            4          Confidence_Feature_ID        esriFieldTypeString
# 5            5               Mode_Observation        esriFieldTypeString
# 6            6                     Slip_Sense        esriFieldTypeString
# 7            7         Scarp_Facing_Direction        esriFieldTypeString
# 8            8                Local_Fault_Dip  esriFieldTypeSmallInteger
# 9            9    Local_Fault_Azimuth_Degrees  esriFieldTypeSmallInteger
# 10          10                   Slip_Azimuth  esriFieldTypeSmallInteger
# 11          11    Fault_Slip_Measurement_Type        esriFieldTypeString
# 12          12                       Heave_cm        esriFieldTypeDouble
# 13          13                   Heave_min_cm        esriFieldTypeDouble
# 14          14                   Heave_max_cm        esriFieldTypeDouble
# 15          15             Rupture_Expression        esriFieldTypeString
# 16          16                Rupture_Width_m        esriFieldTypeDouble
# 17          17            Rupture_Width_Min_m        esriFieldTypeDouble
# 18          18            Rupture_Width_Max_m        esriFieldTypeDouble
# 19          19                VM_Slip_Azimuth  esriFieldTypeSmallInteger
# 20          20                         Plunge  esriFieldTypeSmallInteger
# 21          21          Net_Slip_Preferred_cm        esriFieldTypeDouble
# 22          22                Net_Slip_Min_cm        esriFieldTypeDouble
# 23          23                Net_Slip_Max_cm        esriFieldTypeDouble
# 24          24  Vector_Measurement_Confidence        esriFieldTypeString
# 25          25    Vector_Offset_Feature_Notes        esriFieldTypeString
# 26          26       Horizontal_Separation_cm        esriFieldTypeDouble
# 27          27   Horizontal_Separation_Min_cm        esriFieldTypeDouble
# 28          28   Horizontal_Separation_Max_cm        esriFieldTypeDouble
# 29          29         Vertical_Separation_cm        esriFieldTypeDouble
# 30          30     Vertical_Separation_Min_cm        esriFieldTypeDouble
# 31          31     Vertical_Separation_Max_cm        esriFieldTypeDouble
# 32          32    Slip_Measurement_Confidence        esriFieldTypeString
# 33          33      Slip_Offset_Feature_Notes        esriFieldTypeString
# 34          34                     Diameter_m        esriFieldTypeDouble
# 35          35           Height_of_Material_m        esriFieldTypeDouble
# 36          36        Estimated_Max_VertMov_m        esriFieldTypeDouble
# 37          37           LQ_Area_Affected_sqm        esriFieldTypeString
# 38          38               Date_of_Movement        esriFieldTypeString
# 39          39            Displacement_Amount        esriFieldTypeString
# 40          40               Est_Direction_SM        esriFieldTypeString
# 41          41              Landslide_Feature        esriFieldTypeString
# 42          42                     Slide_Type        esriFieldTypeString
# 43          43                  Material_Type        esriFieldTypeString
# 44          44                          Depth        esriFieldTypeString
# 45          45           SM_Area_Affected_sqm        esriFieldTypeString
# 46          46           Est_Max_Drop_Elev_ft        esriFieldTypeDouble
# 47          47       Length_Exposed_Downslope        esriFieldTypeString
# 48          48                Cause_of_Damage        esriFieldTypeString
# 49          49              Facility_Affected        esriFieldTypeString
# 50          50               Utility_Affected        esriFieldTypeString
# 51          51                Damage_Severity        esriFieldTypeString
# 52          52                       GlobalID      esriFieldTypeGlobalID
# 53          53                   CreationDate          esriFieldTypeDate
# 54          54                        Creator        esriFieldTypeString
# 55          55                       EditDate          esriFieldTypeDate
# 56          56                         Editor        esriFieldTypeString
#
#                                                       Alias
# 0                                                  OBJECTID
# 1   Station ID (Initials_sequential number (i.e., TED_001))
# 2                                                   Feature
# 3                                                     Notes
# 4                                  Confidence in Feature ID
# 5                                       Mode of Observation
# 6                                                Slip Sense
# 7                                    Scarp Facing Direction
# 8                  Local Fault Dip (0-90°; right hand rule)
# 9     Local Fault Azimuth Degrees (0-360°; right hand rule)
# 10                                    Slip Azimuth (0-360°)
# 11                      Fault Slip Measurement, Select Type
# 12                                     Heave Preferred (cm)
# 13                                           Heave Min (cm)
# 14                                           Heave Max (cm)
# 15                                       Rupture Expression
# 16                              Rupture Width Preferred (m)
# 17                                    Rupture Width Min (m)
# 18                                    Rupture Width Max (m)
# 19                             Slip Vector Azimuth (0-360°)
# 20                               Slip Vector Plunge (0-90°)
# 21                                      Slip Preferred (cm)
# 22                                            Slip Min (cm)
# 23                                            Slip Max (cm)
# 24                            Vector Measurement Confidence
# 25                                 Vector Measurement Notes
# 26                     Horizontal Separation Preferred (cm)
# 27                           Horizontal Separation Min (cm)
# 28                           Horizontal Separation Max (cm)
# 29                       Vertical Separation Preferred (cm)
# 30                             Vertical Separation Min (cm)
# 31                             Vertical Separation Max (cm)
# 32                              Slip Measurement Confidence
# 33                                   Slip Measurement Notes
# 34                                             Diameter (m)
# 35                                   Height of Material (m)
# 36                  Estimated Maximum Vertical Movement (m)
# 37                                    Area Affected (sq. m)
# 38                         Date of Movement (YYYYMMDD_Time)
# 39                                      Displacement Amount
# 40           Estimated Direction of Slope Movement (0-360°)
# 41                                        Landslide Feature
# 42                                               Slide Type
# 43                                            Material Type
# 44                                                    Depth
# 45                                     Area Affected (sq m)
# 46                     Estimated Max Drop in Elevation (ft)
# 47                                 Length Exposed Downslope
# 48                                          Cause of Damage
# 49                                        Facility Affected
# 50                                         Utility Affected
# 51                                          Damage Severity
# 52                                                 GlobalID
# 53                                             CreationDate
# 54                                                  Creator
# 55                                                 EditDate
# 56                                                   Editor

# %%
# # pull directly from AGOL, save as csv

from arcgis.gis import GIS
from arcgis.features import FeatureLayerCollection

# # Connect to ArcGIS Online or your Enterprise portal
# # gis = GIS("home")  # Use "home" if you're already logged in
# gis = GIS("https://www.arcgis.com", "my_username", "my_password")

# # Replace with your item ID
# item_id = "4659de32b8514b34bf842321b05c0e63"  # <- your item ID here

# # Get the item and its feature layer(s)
# item = gis.content.get(item_id)
# flc = FeatureLayerCollection.fromitem(item)
# layer = flc.layers[0]  # Or loop if you want all layers

# # Create the DataFrame
# schema_df = pd.DataFrame([
#     {
#         "Field Name": field["name"],
#         "Field Type": field["type"],
#         "Alias": field.get("alias", "")
#     }
#     for field in layer.properties.fields
# ])

# # Display the DataFrame
# display(schema_df)

# schema_df.to_csv(post_ridgecrest_schema_local_filename)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[20], line 14
#      11 item_id = "4659de32b8514b34bf842321b05c0e63"  # <- your item ID here
#      13 # Get the item and its feature layer(s)
# ---> 14 item = gis.content.get(item_id)
#      15 flc = FeatureLayerCollection.fromitem(item)
#      16 layer = flc.layers[0]  # Or loop if you want all layers
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\__init__.py:7747, in ContentManager.get(self, itemid)
#    7745         return None
#    7746     else:
# -> 7747         raise e
#    7749 if item is not None:
#    7750     return Item(self._gis, itemid, item)
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\__init__.py:7737, in ContentManager.get(self, itemid)
#    7724 """
#    7725 The ``get`` method returns the :class:`~arcgis.gis.Item` object for the specified itemid.
#    7726
#    (...)   7734     The item object if the item is found, None if the item is not found.
#    7735 """
#    7736 try:
# -> 7737     item = self._portal.get_item(itemid)
#    7738 except RuntimeError as re:
#    7739     if re.args[0].__contains__("Item does not exist or is inaccessible"):
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\_impl\_portalpy.py:1430, in Portal.get_item(self, itemid)
#    1366 def get_item(self, itemid: str):
#    1367     """Returns the item information for the specified item.
#    1368
#    1369     Arguments
#    (...)   1428         ================  ========================================================
#    1429     """
# -> 1430     return self.con.post("content/items/" + itemid, self._postdata())
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1529, in Connection.post(self, path, params, files, **kwargs)
#    1527 if return_raw_response:
#    1528     return resp
# -> 1529 return self._handle_response(
#    1530     resp=resp,
#    1531     out_path=out_path,
#    1532     file_name=file_name,
#    1533     try_json=try_json,
#    1534     force_bytes=kwargs.pop("force_bytes", False),
#    1535 )
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1004, in Connection._handle_response(self, resp, file_name, out_path, try_json, force_bytes, ignore_error_key)
#    1002             return data
#    1003         errorcode = data["error"]["code"] if "code" in data["error"] else 0
# -> 1004         self._handle_json_error(data["error"], errorcode)
#    1005     return data
#    1006 else:
#
# File c:\Users\rajuv\AppData\Local\Programs\Python\Python311\Lib\site-packages\arcgis\gis\_impl\_con\_connection.py:1027, in Connection._handle_json_error(self, error, errorcode)
#    1024                 # _log.error(errordetail)
#    1026 errormessage = errormessage + "\n(Error Code: " + str(errorcode) + ")"
# -> 1027 raise Exception(errormessage)
#
# Exception: You do not have permissions to access this resource or perform this operation.
# (Error Code: 403)

# %%
# # Fixed complete schema comparison across all three datasets

# # Define the helper function first
# def get_current_field_meaning(field_name):
#     """Get the meaning/alias for a specific field name in current schema"""
#     row = df_current_schema[df_current_schema['Field Name'] == field_name]
#     if not row.empty:
#         return row['Alias'].iloc[0]
#     else:
#         return f"Field '{field_name}' not found"

# # Create standardized schema comparison across all three datasets
# current_schema_standardized = df_current_schema[['Field Name', 'Alias']].copy()
# current_schema_standardized.columns = ['Field', 'Definition']
# current_schema_standardized['Dataset'] = 'Current (Post-Ridgecrest)'

# # Add dataset labels to existing schemas
# napa_schema_labeled = napa_merged_schema.copy()
# napa_schema_labeled['Dataset'] = 'Napa (2014)'

# ridgecrest_schema_labeled = ridgecrest_schema_df.copy()
# ridgecrest_schema_labeled['Dataset'] = 'Ridgecrest (2019)'

# # Combine all schemas
# all_schemas = pd.concat([
#     napa_schema_labeled[['Field', 'Definition', 'Dataset']], 
#     ridgecrest_schema_labeled[['Field', 'Definition', 'Dataset']], 
#     current_schema_standardized[['Field', 'Definition', 'Dataset']]
# ], ignore_index=True)

# print("Schema Evolution Summary:")
# print("=" * 25)
# print(f"Napa (2014): {len(napa_schema_labeled)} fields")
# print(f"Ridgecrest (2019): {len(ridgecrest_schema_labeled)} fields")  
# print(f"Current (Post-Ridgecrest): {len(current_schema_standardized)} fields")

# # Find common fields across datasets
# napa_fields = set(napa_schema_labeled['Field'].dropna())
# ridgecrest_fields = set(ridgecrest_schema_labeled['Field'].dropna())
# current_fields = set(current_schema_standardized['Field'].dropna())

# # Core fields present in all three schemas
# common_all_three = napa_fields & ridgecrest_fields & current_fields
# print(f"\nFields common to all three schemas: {len(common_all_three)}")
# if common_all_three:
#     print("Common fields:", sorted(list(common_all_three)))

# # Fields unique to each dataset
# current_only = current_fields - napa_fields - ridgecrest_fields
# ridgecrest_only = ridgecrest_fields - napa_fields
# napa_only = napa_fields - ridgecrest_fields - current_fields

# # Find overlaps between datasets
# napa_ridgecrest_common = napa_fields & ridgecrest_fields
# current_ridgecrest_common = current_fields & ridgecrest_fields
# current_napa_common = current_fields & napa_fields

# print(f"\nDataset Overlaps:")
# print(f"Napa-Ridgecrest common: {len(napa_ridgecrest_common)}")
# print(f"Current-Ridgecrest common: {len(current_ridgecrest_common)}")
# print(f"Current-Napa common: {len(current_napa_common)}")

# print(f"\nUnique to each dataset:")
# print(f"Unique to Napa only: {len(napa_only)}")
# print(f"New in Ridgecrest (not in Napa): {len(ridgecrest_only)}")
# print(f"New in Current (not in Napa or Ridgecrest): {len(current_only)}")

# # Analyze field categories in current schema
# def categorize_current_fields():
#     """Categorize current schema fields by purpose"""
#     categories = {
#         'Identification': [],
#         'Location': [],
#         'Observation_Metadata': [],
#         'Fault_Geometry': [],
#         'Slip_Measurements': [],
#         'Confidence_Quality': [],
#         'Secondary_Effects': [],
#         'System_Fields': []
#     }
    
#     for _, row in df_current_schema.iterrows():
#         field = row['Field Name']
#         alias = str(row['Alias']).lower()
#         field_lower = field.lower()
        
#         if any(word in field_lower for word in ['id', 'station']):
#             categories['Identification'].append(field)
#         elif any(word in alias for word in ['latitude', 'longitude', 'coordinate', 'location']):
#             categories['Location'].append(field)  
#         elif any(word in alias for word in ['observer', 'date', 'time', 'mode']) or 'observation' in alias:
#             categories['Observation_Metadata'].append(field)
#         elif any(word in alias for word in ['fault', 'dip', 'azimuth', 'strike', 'scarp']):
#             categories['Fault_Geometry'].append(field)
#         elif any(word in alias for word in ['slip', 'displacement', 'separation', 'offset', 'heave']):
#             categories['Slip_Measurements'].append(field)
#         elif any(word in alias for word in ['confidence', 'quality', 'notes']):
#             categories['Confidence_Quality'].append(field)
#         elif any(word in alias for word in ['landslide', 'liquefaction', 'damage', 'slope']):
#             categories['Secondary_Effects'].append(field)
#         elif any(word in field_lower for word in ['globalid', 'objectid', 'creation', 'edit']):
#             categories['System_Fields'].append(field)
#         else:
#             # Default to observation metadata for uncategorized
#             categories['Observation_Metadata'].append(field)
    
#     return categories

# categories = categorize_current_fields()

# print("\nCurrent Schema Field Categories:")
# print("=" * 35)
# for category, fields in categories.items():
#     if fields:  # Only show categories with fields
#         print(f"\n{category.replace('_', ' ')} ({len(fields)} fields):")
#         for field in fields:
#             meaning = get_current_field_meaning(field)
#             print(f"  - {field}: {meaning}")

# # Create a comparison table for key measurement fields
# key_measurements = ['horizontal', 'vertical', 'slip', 'offset', 'displacement', 'azimuth']

# def find_measurement_fields(schema_df, field_col='Field'):
#     """Find measurement-related fields in a schema"""
#     measurement_fields = []
#     for _, row in schema_df.iterrows():
#         field = str(row[field_col]).lower()
#         if any(keyword in field for keyword in key_measurements):
#             measurement_fields.append(row[field_col])
#     return measurement_fields

# print("\nMeasurement Field Evolution:")
# print("=" * 30)
# napa_measurements = find_measurement_fields(napa_schema_labeled)
# ridgecrest_measurements = find_measurement_fields(ridgecrest_schema_labeled)
# current_measurements = find_measurement_fields(current_schema_standardized)

# print(f"Napa measurement fields ({len(napa_measurements)}): {napa_measurements}")
# print(f"Ridgecrest measurement fields ({len(ridgecrest_measurements)}): {ridgecrest_measurements}")  
# print(f"Current measurement fields ({len(current_measurements)}): {current_measurements}")

# # Show some specific field comparisons
# print("\nField Name Evolution Examples:")
# print("=" * 35)

# # Look for similar concepts across schemas
# concept_mappings = {
#     'Station/Site ID': ['stnid', 'intid', 'Station_ID'],
#     'Observer Info': ['observer', 'observer', 'Creator'],
#     'Fault Azimuth': ['fault_azimuth', 'fault_az_pref', 'Local_Fault_Azimuth_Degrees'],
#     'Horizontal Offset': ['ss_displacement', 'horiz_offset_pref', 'Horizontal_Separation_cm'],
#     'Vertical Offset': ['vert_offset', 'vert_offset_pref', 'Vertical_Separation_cm']
# }

# for concept, field_names in concept_mappings.items():
#     print(f"\n{concept}:")
#     datasets = ['Napa', 'Ridgecrest', 'Current']
#     for i, (dataset, field_name) in enumerate(zip(datasets, field_names)):
#         print(f"  {dataset}: {field_name}")
# Out:
# Schema Evolution Summary:
# =========================
# Napa (2014): 21 fields
# Ridgecrest (2019): 63 fields
# Current (Post-Ridgecrest): 57 fields
#
# Fields common to all three schemas: 0
#
# Dataset Overlaps:
# Napa-Ridgecrest common: 11
# Current-Ridgecrest common: 0
# Current-Napa common: 0
#
# Unique to each dataset:
# Unique to Napa only: 10
# New in Ridgecrest (not in Napa): 52
# New in Current (not in Napa or Ridgecrest): 57
#
# Current Schema Field Categories:
# ===================================
#
# Identification (11 fields):
#   - OBJECTID: OBJECTID
#   - Station_ID: Station ID (Initials_sequential number (i.e., TED_001))
#   - Confidence_Feature_ID: Confidence in Feature ID
#   - Rupture_Width_m: Rupture Width Preferred (m)
#   - Rupture_Width_Min_m: Rupture Width Min (m)
#   - Rupture_Width_Max_m: Rupture Width Max (m)
#   - Vector_Measurement_Confidence: Vector Measurement Confidence
#   - Slip_Measurement_Confidence: Slip Measurement Confidence
#   - Landslide_Feature: Landslide Feature
#   - Slide_Type: Slide Type
#   - GlobalID: GlobalID
#
# Observation Metadata (17 fields):
#   - Feature_Origin: Feature
#   - Mode_Observation: Mode of Observation
#   - Rupture_Expression: Rupture Expression
#   - Diameter_m: Diameter (m)
#   - Height_of_Material_m: Height of Material (m)
#   - Estimated_Max_VertMov_m: Estimated Maximum Vertical Movement (m)
#   - LQ_Area_Affected_sqm: Area Affected (sq. m)
#   - Date_of_Movement: Date of Movement (YYYYMMDD_Time)
#   - Material_Type: Material Type
#   - Depth: Depth
#   - SM_Area_Affected_sqm: Area Affected (sq m)
#   - Est_Max_Drop_Elev_ft: Estimated Max Drop in Elevation (ft)
#   - Facility_Affected: Facility Affected
#   - Utility_Affected: Utility Affected
#   - CreationDate: CreationDate
#   - Creator: Creator
#   - EditDate: EditDate
#
# Fault Geometry (6 fields):
#   - Scarp_Facing_Direction: Scarp Facing Direction
#   - Local_Fault_Dip: Local Fault Dip (0-90°; right hand rule)
#   - Local_Fault_Azimuth_Degrees: Local Fault Azimuth Degrees (0-360°; right hand rule)
#   - Slip_Azimuth: Slip Azimuth (0-360°)
#   - Fault_Slip_Measurement_Type: Fault Slip Measurement, Select Type
#   - VM_Slip_Azimuth: Slip Vector Azimuth (0-360°)
#
# Slip Measurements (16 fields):
#   - Slip_Sense: Slip Sense
#   - Heave_cm: Heave Preferred (cm)
#   - Heave_min_cm: Heave Min (cm)
#   - Heave_max_cm: Heave Max (cm)
#   - Plunge: Slip Vector Plunge (0-90°)
#   - Net_Slip_Preferred_cm: Slip Preferred (cm)
#   - Net_Slip_Min_cm: Slip Min (cm)
#   - Net_Slip_Max_cm: Slip Max (cm)
#   - Horizontal_Separation_cm: Horizontal Separation Preferred (cm)
#   - Horizontal_Separation_Min_cm: Horizontal Separation Min (cm)
#   - Horizontal_Separation_Max_cm: Horizontal Separation Max (cm)
#   - Vertical_Separation_cm: Vertical Separation Preferred (cm)
#   - Vertical_Separation_Min_cm: Vertical Separation Min (cm)
#   - Vertical_Separation_Max_cm: Vertical Separation Max (cm)
#   - Slip_Offset_Feature_Notes: Slip Measurement Notes
#   - Displacement_Amount: Displacement Amount
#
# Confidence Quality (2 fields):
#   - Notes: Notes
#   - Vector_Offset_Feature_Notes: Vector Measurement Notes
#
# Secondary Effects (4 fields):
#   - Est_Direction_SM: Estimated Direction of Slope Movement (0-360°)
#   - Length_Exposed_Downslope: Length Exposed Downslope
#   - Cause_of_Damage: Cause of Damage
#   - Damage_Severity: Damage Severity
#
# System Fields (1 fields):
#   - Editor: Editor
#
# Measurement Field Evolution:
# ==============================
# Napa measurement fields (5): ['fault_azimuth', 'ss_displacement', 'ext_offset', 'comp_offset', 'vert_offset']
# Ridgecrest measurement fields (8): ['horiz_offset_min', 'horiz_offset_pref', 'horiz_offset_max', 'horiz_slip_type', 'vert_offset_min', 'vert_offset_pref', 'vert_offset_max', 'vert_slip_type']
# Current measurement fields (18): ['Slip_Sense', 'Local_Fault_Azimuth_Degrees', 'Slip_Azimuth', 'Fault_Slip_Measurement_Type', 'VM_Slip_Azimuth', 'Net_Slip_Preferred_cm', 'Net_Slip_Min_cm', 'Net_Slip_Max_cm', 'Vector_Offset_Feature_Notes', 'Horizontal_Separation_cm', 'Horizontal_Separation_Min_cm', 'Horizontal_Separation_Max_cm', 'Vertical_Separation_cm', 'Vertical_Separation_Min_cm', 'Vertical_Separation_Max_cm', 'Slip_Measurement_Confidence', 'Slip_Offset_Feature_Notes', 'Displacement_Amount']
#
# Field Name Evolution Examples:
# ===================================
#
# Station/Site ID:
#   Napa: stnid
#   Ridgecrest: intid
#   Current: Station_ID
#
# Observer Info:
#   Napa: observer
#   Ridgecrest: observer
#   Current: Creator
#
# Fault Azimuth:
#   Napa: fault_azimuth
#   Ridgecrest: fault_az_pref
#   Current: Local_Fault_Azimuth_Degrees
#
# Horizontal Offset:
#   Napa: ss_displacement
#   Ridgecrest: horiz_offset_pref
#   Current: Horizontal_Separation_cm
#
# Vertical Offset:
#   Napa: vert_offset
#   Ridgecrest: vert_offset_pref
#   Current: Vertical_Separation_cm
